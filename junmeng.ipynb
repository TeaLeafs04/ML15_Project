# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("airbnb.csv")
df
# Out:
#             id property_type        room_type  \
# 0      6242629     Apartment     Private room
# 1     18688272     Apartment     Private room
# 2     15435501     Apartment     Private room
# 3     15822779         House     Private room
# 4     10752305     Apartment  Entire home/apt
# ...        ...           ...              ...
# 4995  18122161         House     Private room
# 4996  11906101     Apartment     Private room
# 4997  12917210         House  Entire home/apt
# 4998  20439522     Apartment  Entire home/apt
# 4999  14483019   Condominium  Entire home/apt
#
#                                               amenities  accommodates  \
# 0     {TV,"Cable TV","Wireless Internet","Air condit...             2
# 1     {Internet,"Wireless Internet","Air conditionin...             2
# 2     {TV,Internet,"Wireless Internet","Air conditio...             2
# 3     {"Wireless Internet",Breakfast,"Pets live on t...             2
# ...

# %%
df["property_type"].value_counts()/50
# Out:
# property_type
# Apartment             64.94
# House                 22.78
# Condominium            3.64
# Townhouse              2.58
# Loft                   1.58
# Other                  0.86
# Guesthouse             0.74
# Bed & Breakfast        0.74
# Bungalow               0.66
# Dorm                   0.26
# In-law                 0.22
# Villa                  0.16
# Hostel                 0.14
# Boutique hotel         0.12
# Cabin                  0.12
# Boat                   0.10
# Guest suite            0.08
# Timeshare              0.06
# Serviced apartment     0.06
# Treehouse              0.04
# Camper/RV              0.04
# Tipi                   0.02
# Hut                    0.02
# Yurt                   0.02
# Tent                   0.02
# Name: count, dtype: float64
