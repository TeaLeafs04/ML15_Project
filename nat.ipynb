# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Dataset/airbnb.csv")
df.sample(10)
# Out:
#             id property_type        room_type  \
# 3813   8130859         House     Private room
# 908    3826620     Apartment     Private room
# 4157  19122738     Apartment     Private room
# 2361  14945624         House  Entire home/apt
# 4648   7808073     Apartment  Entire home/apt
# 1277  10828230     Apartment  Entire home/apt
# 1858  17862095     Apartment  Entire home/apt
# 2068   8870904         House     Private room
# 1541  20163793     Apartment  Entire home/apt
# 1434   4358619     Apartment  Entire home/apt
#
#                                               amenities  accommodates  \
# 3813  {"Wireless Internet","Air conditioning",Kitche...             2
# 908   {TV,Internet,"Wireless Internet","Air conditio...             2
# 4157  {TV,"Cable TV","Wireless Internet",Kitchen,"Pe...             2
# 2361  {TV,"Cable TV",Internet,"Wireless Internet","A...             4
# 4648  {TV,"Cable TV","Wireless Internet","Air condit...             2
# ...

# %%
df.dtypes
# Out:
# id                          int64
# property_type              object
# room_type                  object
# amenities                  object
# accommodates                int64
# bathrooms                 float64
# bed_type                   object
# cancellation_policy        object
# cleaning_fee                 bool
# city                       object
# description                object
# first_review               object
# host_has_profile_pic       object
# host_identity_verified     object
# host_response_rate         object
# host_since                 object
# instant_bookable           object
# last_review                object
# latitude                  float64
# longitude                 float64
# name                       object
# neighbourhood              object
# number_of_reviews           int64
# review_scores_rating        int64
# thumbnail_url              object
# zipcode                     int64
# bedrooms                    int64
# ...

# %%
nyc_station = pd.read_csv("Dataset/metro/NYC.csv")

# %%
sns.scatterplot(df[df["city"] == "NYC"], x="latitude", y="longitude")
sns.scatterplot(nyc_station, x="Y", y="X", color="red")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>
